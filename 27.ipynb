# %%
from Bio import SeqIO
sequences = {}  
for seq_record in SeqIO.parse("C:/Users/Acer/Downloads/aaa.fasta", "fasta"):
    sequences[seq_record.id] = seq_record.seq
#print (sequences.keys())
a = sequences['EF553973.1']
print (a) 
from Bio.Seq import Seq 
n=str(a)
my_seq = Seq(n) 
my_dna = my_seq.transcribe()
my_rna = my_dna.back_transcribe() 
print("РНК:", my_dna)
print("ДНК:", my_rna)
print("Белок:" + my_rna.translate())
# Out:
# ...
# РНК: ...
# ДНК: ...
# Белок:INERTRDETDTFMSLFNKVLHCVVSCLCIINVY*WCFILLIK*RC*YNWYWRLFKFFNVNICNIFTHENNSVHLFSKHRI**MELLLFVLVRVT*NDVIFVHCCDIFNSTSKFCIKRI*DIRNNNTYCSCLLTC*STCY
